# %%
import ROOT
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import uproot


import sys
sys.path.append('../common/')
# import numba as nb
import hepdata_lib as hep
from deco_clock import clock

# ROOT.gInterpreter.ProcessLine('#include "../Ultra-Peripheral Collisions/UPC Code/upcJpsiDimu/common/VertexCompositeTree.h"')

# %%
@clock
def sumit(s):
	sum = 0
	for i in range(s):
		sum+=i
	return sum

sumit(100)
# file_name = "inFiles/dimuana_mc_CohJpsi_sample_1000.root"
# file = uproot.open(file_name)
# file.keys()
# tree = file["dimucontana_mc"]["VertexCompositeNtuple"]
# tree.keys()
# tree.arrays("evtSel[2]")


# a = file["hVzvsVyvsVx"]
# a.to_hist().plot()

# Load style sheet
# plt.style.use(hep.style.CMS)  # or ATLAS/LHCb2

# h, bins = np.histogram(np.random.random(1000))
# fig, ax = plt.subplots()
# hep.histplot(h, bins)

# %%
a = 1
b = 2
if (a and b ):
	print("hello")

# %%
from array import array
x = np.arange(-2.5, 2.5, 0.05, dtype = "d")
a = ROOT.TH1D("a","",len(x)-1, x)

# %%
a = "start"
n = 10
f = "-"
print(f'{a :{f}^{n}} b')

# %%
for i in range(10):
	print(i)
